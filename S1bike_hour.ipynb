# %%
import pandas as pd
import seaborn as sns

# %%
Df = pd.read_csv("bike_datset_hour.csv")
Df
# Out:
#        instant      dteday  season   yr  mnth    hr  holiday  weekday  \
# 0            1  01-01-2011     1.0  0.0   1.0   0.0        0      6.0
# 1            2  01-01-2011     1.0  0.0   1.0   1.0        0      6.0
# 2            3  01-01-2011     1.0  0.0   1.0   2.0        0      6.0
# 3            4  01-01-2011     1.0  0.0   1.0   3.0        0      6.0
# 4            5  01-01-2011     1.0  0.0   1.0   4.0        0      6.0
# ...        ...         ...     ...  ...   ...   ...      ...      ...
# 17374    17375  31-12-2012     NaN  1.0  12.0  19.0        0      1.0
# 17375    17376  31-12-2012     1.0  1.0  12.0  20.0        0      1.0
# 17376    17377  31-12-2012     1.0  1.0  12.0  21.0        0      1.0
# 17377    17378  31-12-2012     1.0  1.0  12.0  22.0        0      1.0
# 17378    17379  31-12-2012     1.0  1.0  12.0  23.0        0      1.0
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# ...

# %%
Df.dtypes
# Out:
# instant         int64
# dteday         object
# season        float64
# yr            float64
# mnth          float64
# hr            float64
# holiday         int64
# weekday       float64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual        float64
# registered    float64
# cnt             int64
# dtype: object

# %%
Df.shape
# Out:
# (17379, 17)

# %%
Df.describe
# Out:
# <bound method NDFrame.describe of        instant      dteday  season   yr  mnth    hr  holiday  weekday  \
# 0            1  01-01-2011     1.0  0.0   1.0   0.0        0      6.0
# 1            2  01-01-2011     1.0  0.0   1.0   1.0        0      6.0
# 2            3  01-01-2011     1.0  0.0   1.0   2.0        0      6.0
# 3            4  01-01-2011     1.0  0.0   1.0   3.0        0      6.0
# 4            5  01-01-2011     1.0  0.0   1.0   4.0        0      6.0
# ...        ...         ...     ...  ...   ...   ...      ...      ...
# 17374    17375  31-12-2012     NaN  1.0  12.0  19.0        0      1.0
# 17375    17376  31-12-2012     1.0  1.0  12.0  20.0        0      1.0
# 17376    17377  31-12-2012     1.0  1.0  12.0  21.0        0      1.0
# 17377    17378  31-12-2012     1.0  1.0  12.0  22.0        0      1.0
# 17378    17379  31-12-2012     1.0  1.0  12.0  23.0        0      1.0
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# ...

# %%
Df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        2
# yr            1
# mnth          1
# hr            1
# holiday       0
# weekday       1
# workingday    0
# weathersit    0
# temp          1
# atemp         2
# hum           0
# windspeed     1
# casual        1
# registered    1
# cnt           0
# dtype: int64

# %%
 (Df==0).sum()
# Out:
# instant           0
# dteday            0
# season            0
# yr             8645
# mnth              0
# hr              726
# holiday       16879
# weekday        2502
# workingday     5514
# weathersit        0
# temp              0
# atemp             2
# hum              22
# windspeed      2180
# casual         1581
# registered       24
# cnt               0
# dtype: int64

# %%
Mean = Df.mean(numeric_only =True)
Mean
# Out:
# instant       8690.000000
# season           2.501813
# yr               0.502532
# mnth             6.537461
# hr              11.546438
# holiday          0.028770
# weekday          3.003510
# workingday       0.682721
# weathersit       1.425283
# temp             0.496992
# atemp            0.475799
# hum              0.627229
# windspeed        0.190101
# casual          35.673208
# registered     153.789849
# cnt            189.463088
# dtype: float64

# %%
replace=Df.fillna(Mean,inplace=True)
replace
Df
# Out:
#        instant      dteday    season   yr  mnth    hr  holiday  weekday  \
# 0            1  01-01-2011  1.000000  0.0   1.0   0.0        0      6.0
# 1            2  01-01-2011  1.000000  0.0   1.0   1.0        0      6.0
# 2            3  01-01-2011  1.000000  0.0   1.0   2.0        0      6.0
# 3            4  01-01-2011  1.000000  0.0   1.0   3.0        0      6.0
# 4            5  01-01-2011  1.000000  0.0   1.0   4.0        0      6.0
# ...        ...         ...       ...  ...   ...   ...      ...      ...
# 17374    17375  31-12-2012  2.501813  1.0  12.0  19.0        0      1.0
# 17375    17376  31-12-2012  1.000000  1.0  12.0  20.0        0      1.0
# 17376    17377  31-12-2012  1.000000  1.0  12.0  21.0        0      1.0
# 17377    17378  31-12-2012  1.000000  1.0  12.0  22.0        0      1.0
# 17378    17379  31-12-2012  1.000000  1.0  12.0  23.0        0      1.0
#
#        workingday  weathersit  temp     atemp   hum  windspeed  casual  \
# ...

# %%
sub1=Df[0:101]
sub1
# Out:
#      instant      dteday  season   yr  mnth   hr  holiday  weekday  \
# 0          1  01-01-2011     1.0  0.0   1.0  0.0        0      6.0
# 1          2  01-01-2011     1.0  0.0   1.0  1.0        0      6.0
# 2          3  01-01-2011     1.0  0.0   1.0  2.0        0      6.0
# 3          4  01-01-2011     1.0  0.0   1.0  3.0        0      6.0
# 4          5  01-01-2011     1.0  0.0   1.0  4.0        0      6.0
# ..       ...         ...     ...  ...   ...  ...      ...      ...
# 96        97  05-01-2011     1.0  0.0   1.0  5.0        0      3.0
# 97        98  05-01-2011     1.0  0.0   1.0  6.0        0      3.0
# 98        99  05-01-2011     1.0  0.0   1.0  7.0        0      3.0
# 99       100  05-01-2011     1.0  0.0   1.0  8.0        0      3.0
# 100      101  05-01-2011     1.0  0.0   1.0  9.0        0      3.0
#
#      workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 0             0           1  0.24  0.2879  0.81     0.0000     3.0
# ...

# %%
sub2=Df.loc[(Df["yr"] == 1)]
sub2
# Out:
#        instant      dteday    season   yr  mnth    hr  holiday  weekday  \
# 8645      8646  01-01-2012  1.000000  1.0   1.0   0.0        0      0.0
# 8646      8647  01-01-2012  1.000000  1.0   1.0   1.0        0      0.0
# 8647      8648  01-01-2012  1.000000  1.0   1.0   2.0        0      0.0
# 8648      8649  01-01-2012  1.000000  1.0   1.0   3.0        0      0.0
# 8649      8650  01-01-2012  1.000000  1.0   1.0   4.0        0      0.0
# ...        ...         ...       ...  ...   ...   ...      ...      ...
# 17374    17375  31-12-2012  2.501813  1.0  12.0  19.0        0      1.0
# 17375    17376  31-12-2012  1.000000  1.0  12.0  20.0        0      1.0
# 17376    17377  31-12-2012  1.000000  1.0  12.0  21.0        0      1.0
# 17377    17378  31-12-2012  1.000000  1.0  12.0  22.0        0      1.0
# 17378    17379  31-12-2012  1.000000  1.0  12.0  23.0        0      1.0
#
#        workingday  weathersit  temp     atemp   hum  windspeed  casual  \
# ...

# %%
imp_cls = Df[["season","yr","holiday","weekday","windspeed"]]
imp_cls
# Out:
#          season   yr  holiday  weekday  windspeed
# 0      1.000000  0.0        0      6.0   0.000000
# 1      1.000000  0.0        0      6.0   0.000000
# 2      1.000000  0.0        0      6.0   0.000000
# 3      1.000000  0.0        0      6.0   0.000000
# 4      1.000000  0.0        0      6.0   0.000000
# ...         ...  ...      ...      ...        ...
# 17374  2.501813  1.0        0      1.0   0.164200
# 17375  1.000000  1.0        0      1.0   0.164200
# 17376  1.000000  1.0        0      1.0   0.164200
# 17377  1.000000  1.0        0      1.0   0.134300
# 17378  1.000000  1.0        0      1.0   0.190101
#
# [17379 rows x 5 columns]

# %%
sub3=Df.loc[(Df["weekday"]==0) & (Df["weathersit"] ==3)]
sub3
# Out:
#        instant      dteday  season   yr  mnth    hr  holiday  weekday  \
# 29          30  02-01-2011     1.0  0.0   1.0   6.0        0      0.0
# 31          32  02-01-2011     1.0  0.0   1.0   8.0        0      0.0
# 37          38  02-01-2011     1.0  0.0   1.0  14.0        0      0.0
# 38          39  02-01-2011     1.0  0.0   1.0  15.0        0      0.0
# 39          40  02-01-2011     1.0  0.0   1.0  16.0        0      0.0
# ...        ...         ...     ...  ...   ...   ...      ...      ...
# 16849    16850  09-12-2012     4.0  1.0  12.0  20.0        0      0.0
# 16851    16852  09-12-2012     4.0  1.0  12.0  22.0        0      0.0
# 16852    16853  09-12-2012     4.0  1.0  12.0  23.0        0      0.0
# 16998    16999  16-12-2012     4.0  1.0  12.0   1.0        0      0.0
# 17015    17016  16-12-2012     4.0  1.0  12.0  18.0        0      0.0
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# ...

# %%
sub4=Df.loc[Df["weathersit"]==3]
sub4
# Out:
#        instant      dteday  season   yr  mnth    hr  holiday  weekday  \
# 18          19  01-01-2011     1.0  0.0   1.0  18.0        0      6.0
# 19          20  01-01-2011     1.0  0.0   1.0  19.0        0      6.0
# 29          30  02-01-2011     1.0  0.0   1.0   6.0        0      0.0
# 31          32  02-01-2011     1.0  0.0   1.0   8.0        0      0.0
# 37          38  02-01-2011     1.0  0.0   1.0  14.0        0      0.0
# ...        ...         ...     ...  ...   ...   ...      ...      ...
# 17260    17261  27-12-2012     1.0  1.0  12.0   1.0        0      4.0
# 17317    17318  29-12-2012     1.0  1.0  12.0  10.0        0      6.0
# 17318    17319  29-12-2012     1.0  1.0  12.0  11.0        0      6.0
# 17319    17320  29-12-2012     1.0  1.0  12.0  12.0        0      6.0
# 17320    17321  29-12-2012     1.0  1.0  12.0  13.0        0      6.0
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# ...

# %%
k=sub4[10:151]
k
# Out:
#       instant      dteday  season   yr  mnth    hr  holiday  weekday  \
# 169       170  08-01-2011     1.0  0.0   1.0   8.0        0      6.0
# 170       171  08-01-2011     1.0  0.0   1.0   9.0        0      6.0
# 249       250  11-01-2011     1.0  0.0   1.0  18.0        0      2.0
# 250       251  11-01-2011     1.0  0.0   1.0  19.0        0      2.0
# 251       252  11-01-2011     1.0  0.0   1.0  20.0        0      2.0
# ...       ...         ...     ...  ...   ...   ...      ...      ...
# 1570     1571  10-03-2011     1.0  0.0   3.0  21.0        0      4.0
# 1572     1573  10-03-2011     1.0  0.0   3.0  23.0        0      4.0
# 1574     1575  11-03-2011     1.0  0.0   3.0   1.0        0      5.0
# 1575     1576  11-03-2011     1.0  0.0   3.0   2.0        0      5.0
# 1686     1687  15-03-2011     1.0  0.0   3.0  21.0        0      2.0
#
#       workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 169            0           3  0.16  0.1818  0.93     0.1045     0.0
# ...
