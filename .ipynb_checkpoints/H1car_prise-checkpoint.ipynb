# %%
import pandas as pd

# %%
df = pd.read_csv("Car_Price_dataset.csv")

# %%
df.head(100)
# Out:
#     car_ID  symboling                   CarName fueltype aspiration  \
# 0        1          3        alfa-romero giulia      gas        std
# 1        2          3       alfa-romero stelvio      gas        std
# 2        3          1  alfa-romero Quadrifoglio      gas        std
# 3        4          2               audi 100 ls      gas        std
# 4        5          2                audi 100ls      gas        std
# ..     ...        ...                       ...      ...        ...
# 95      96          1               nissan juke      gas        std
# 96      97          1              nissan latio      gas        std
# 97      98          1               nissan note      gas        std
# 98      99          2            nissan clipper      gas        std
# 99     100          0              nissan rogue      gas        std
#
#    doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0         two  convertible        rwd          front       88.6  ...
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.816500  174.049268   65.928218   53.731683
# std     59.322565    1.245307    6.004449   12.337289    2.136275    2.433707
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.200000   52.000000
# 50%    103.000000    1.000000   97.200000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize  boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.00000  205.000000        205.000000
# mean   2554.808824  126.907317    3.33010    3.254412         10.155271
# ...

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight          float64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg             float64
# highwaympg          float64
# price               float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           5
# carlength           0
# carwidth            3
# carheight           3
# curbweight          1
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           4
# stroke              1
# compressionratio    2
# horsepower          0
# peakrpm             0
# citympg             3
# highwaympg          2
# price               0
# dtype: int64

# %%
 (df == 0).sum()
# Out:
# car_ID               0
# symboling           67
# CarName              0
# fueltype             0
# aspiration           0
# doornumber           0
# carbody              0
# drivewheel           0
# enginelocation       0
# wheelbase            0
# carlength            0
# carwidth             0
# carheight            0
# curbweight           0
# enginetype           0
# cylindernumber       0
# enginesize           0
# fuelsystem           0
# boreratio            0
# stroke               0
# compressionratio     0
# horsepower           0
# peakrpm              0
# citympg              0
# highwaympg           0
# price                0
# dtype: int64

# %%
mean = df.mean(numeric_only = True)
mean
# Out:
# car_ID                103.000000
# symboling               0.834146
# wheelbase              98.816500
# carlength             174.049268
# carwidth               65.928218
# carheight              53.731683
# curbweight           2554.808824
# enginesize            126.907317
# boreratio               3.330100
# stroke                  3.254412
# compressionratio       10.155271
# horsepower            104.117073
# peakrpm              5125.121951
# citympg                25.277228
# highwaympg             30.822660
# price               13276.710571
# dtype: float64

# %%
df3 = df.fillna (mean,inplace = True)
df3

# %%
sub1=df[0:101]
sub1
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 96       97          1              nissan latio      gas        std
# 97       98          1               nissan note      gas        std
# 98       99          2            nissan clipper      gas        std
# 99      100          0              nissan rogue      gas        std
# 100     101          0              nissan nv200      gas        std
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# ...

# %%
sub2 = df.loc[(df['fueltype'] == 'gas') & (df['doornumber'] == 'four')]
sub2
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 3         4          2      audi 100 ls      gas        std       four
# 4         5          2       audi 100ls      gas        std       four
# 6         7          1       audi 100ls      gas        std       four
# 7         8          1        audi 5000      gas        std       four
# 8         9          1        audi 4000      gas      turbo       four
# ..      ...        ...              ...      ...        ...        ...
# 199     200         -1     volvo diesel      gas      turbo       four
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# ...

# %%
sub3 = df[["CarName","fueltype","doornumber","carbody"]]
sub3
# Out:
#                       CarName fueltype doornumber      carbody
# 0          alfa-romero giulia      gas        two  convertible
# 1         alfa-romero stelvio      gas        two  convertible
# 2    alfa-romero Quadrifoglio      gas        two    hatchback
# 3                 audi 100 ls      gas       four        sedan
# 4                  audi 100ls      gas       four        sedan
# ..                        ...      ...        ...          ...
# 200           volvo 145e (sw)      gas       four        sedan
# 201               volvo 144ea      gas       four        sedan
# 202               volvo 244dl      gas       four        sedan
# 203                 volvo 246   diesel       four        sedan
# 204               volvo 264gl      gas       four        sedan
#
# [205 rows x 4 columns]

# %%
sub4 = df.loc[(df["wheelbase"]>84) & (df["enginesize"]>140)]
sub4
# Out:
#      car_ID  symboling                          CarName fueltype aspiration  \
# 2         3          1         alfa-romero Quadrifoglio      gas        std
# 12       13          0                           bmw x1      gas        std
# 13       14          0                           bmw x3      gas        std
# 14       15          1                           bmw z4      gas        std
# 15       16          0                           bmw x4      gas        std
# 16       17          0                           bmw x5      gas        std
# 17       18          0                           bmw x3      gas        std
# 29       30          3        dodge coronet custom (sw)      gas      turbo
# 47       48          0                        jaguar xj      gas        std
# 48       49          0                        jaguar xf      gas        std
# 49       50          0                        jaguar xk      gas        std
# ...

# %%
subset = sub4.loc[(sub4["fueltype"] == "gas")]
subset
# Out:
#      car_ID  symboling                          CarName fueltype aspiration  \
# 2         3          1         alfa-romero Quadrifoglio      gas        std
# 12       13          0                           bmw x1      gas        std
# 13       14          0                           bmw x3      gas        std
# 14       15          1                           bmw z4      gas        std
# 15       16          0                           bmw x4      gas        std
# 16       17          0                           bmw x5      gas        std
# 17       18          0                           bmw x3      gas        std
# 29       30          3        dodge coronet custom (sw)      gas      turbo
# 47       48          0                        jaguar xj      gas        std
# 48       49          0                        jaguar xf      gas        std
# 49       50          0                        jaguar xk      gas        std
# ...

# %%
import sklearn 
from sklearn.model_selection import train_test_split

# %%
train , test = train_test_split(df,test_size =0.2 , random_state = 42)

# %%
train
# Out:
#      car_ID  symboling                CarName fueltype aspiration doornumber  \
# 66       67          0          mazda rx-7 gs   diesel        std       four
# 111     112          0            peugeot 504      gas        std       four
# 153     154          0  toyota corona hardtop      gas        std       four
# 96       97          1           nissan latio      gas        std       four
# 38       39          0       honda civic 1300      gas        std        two
# ..      ...        ...                    ...      ...        ...        ...
# 106     107          1         nissan clipper      gas        std        two
# 14       15          1                 bmw z4      gas        std       four
# 92       93          1           nissan latio      gas        std       four
# 179     180          3          toyota corona      gas        std        two
# 102     103          0            nissan fuga      gas        std       four
#
# ...

# %%
test
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 15       16          0                    bmw x4      gas        std
# 9        10          0       audi 5000s (diesel)      gas      turbo
# 100     101          0              nissan nv200      gas        std
# 132     133          3                  saab 99e      gas        std
# 68       69         -1  buick century luxus (sw)   diesel      turbo
# 95       96          1               nissan juke      gas        std
# 159     160          0            toyota corolla   diesel        std
# 162     163          0            toyota mark ii      gas        std
# 147     148          0            subaru tribeca      gas        std
# 182     183          2          vokswagen rabbit   diesel        std
# 191     192          0         volkswagen rabbit      gas        std
# 164     165          1             toyota corona      gas        std
# 65       66          0                 mazda glc      gas        std
# ...
