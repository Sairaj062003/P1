# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
dataset1 = pd.read_csv('Admission_Predict.csv')
dataset1
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %%
dataset1.shape
# Out:
# (400, 9)

# %%
dataset1.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  400.000000  400.000000   400.000000         400.000000  400.000000
# mean   200.500000  316.807500   107.410000           3.087500    3.400000
# std    115.614301   11.473646     6.069514           1.143728    1.006869
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    100.750000  308.000000   103.000000           2.000000    2.500000
# 50%    200.500000  317.000000   107.000000           3.000000    3.500000
# 75%    300.250000  325.000000   112.000000           4.000000    4.000000
# max    400.000000  340.000000   120.000000           5.000000    5.000000
#
#              LOR         CGPA    Research  Chance of Admit
# count  400.000000  400.000000  400.000000        400.000000
# mean     3.452500    8.598925    0.547500          0.724350
# std      0.898478    0.596317    0.498362          0.142609
# min      1.000000    6.800000    0.000000          0.340000
# ...

# %%
dataset1.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
dataset1.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
sns.pairplot(dataset1)

# %%
sns.histplot(dataset1['GRE Score'], kde=True, bins=30)
plt.title('GRE SCORE')
plt.xlabel('GRE Marks')
plt.ylabel('Frequency')
plt.show()

# %%
plt.bar(dataset1.SOP,dataset1.CGPA,color = ['red'])
plt.xlabel('SOP')
plt.ylabel('CGPA')
plt.title("SOP VS CGPA")
# Out:
# Text(0.5, 1.0, 'SOP VS CGPA')

# %%
dataset1["Admitted"] = 0  
dataset1.loc[dataset1["Chance of Admit "] >= 0.85, "Admitted"] = 1

# %%
dataset1
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit   Admitted
# ...

# %%
dataset1.drop("Chance of Admit", axis=1, inplace=True)
dataset1.drop("Serial No.", axis=1, inplace=True)

# %%
dataset1
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research  \
# 0          337          118                  4  4.5   4.5  9.65         1
# 1          324          107                  4  4.0   4.5  8.87         1
# 2          316          104                  3  3.0   3.5  8.00         1
# 3          322          110                  3  3.5   2.5  8.67         1
# 4          314          103                  2  2.0   3.0  8.21         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 395        324          110                  3  3.5   3.5  9.04         1
# 396        325          107                  3  3.0   3.5  9.11         1
# 397        330          116                  4  5.0   4.5  9.45         1
# 398        312          103                  3  3.5   4.0  8.78         0
# 399        333          117                  4  5.0   4.0  9.66         1
#
#      Admitted
# 0           1
# 1           0
# 2           0
# 3           0
# ...

# %%
sns.pairplot(dataset1, hue='Admitted', vars=['GRE Score', 'TOEFL Score', 'CGPA', 'University Rating'])
plt.show()

# %%
sns.scatterplot(data=dataset1, x='GRE Score', y='CGPA', hue='Admitted', style='Admitted', palette='Set2', markers={0: 'o', 1: 's'})
plt.title('Scatter Plot of GRE Score vs CGPA')
plt.xlabel('GRE Score')
plt.ylabel('CGPA')
plt.legend(title='Admitted', loc='upper left')
plt.show()

# %%
plt.figure(figsize=(8, 5))
admission_counts = dataset1['Admitted'].value_counts()
plt.pie(admission_counts, labels=['Not Admitted', 'Admitted'], autopct='%1.1f%%', colors=['green', 'red'])
plt.title('Admission Status Distribution')
plt.show()

# %%
print(dataset1.columns)
print(dataset1.shape)
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research', 'Admitted'],
#       dtype='object')
# (400, 8)

# %%
y = dataset1.iloc[:,7]

# %%
x = dataset1[["GRE Score", "TOEFL Score", "University Rating", "SOP", "LOR ", "CGPA", "Research"]]  
y = dataset1["Admitted"]

# %%
from sklearn.model_selection import train_test_split



x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.25)

# %%
x_train
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 250        320          104                  3  3.0   2.5  8.57         1
# 63         315          107                  2  4.0   3.0  8.50         1
# 312        311          107                  4  4.5   4.5  9.00         1
# 159        297          100                  1  1.5   2.0  7.90         0
# 283        321          111                  3  2.5   3.0  8.90         1
# ..         ...          ...                ...  ...   ...   ...       ...
# 323        305          102                  2  2.0   2.5  8.18         0
# 192        322          114                  5  4.5   4.0  8.94         1
# 117        290          104                  4  2.0   2.5  7.46         0
# 47         339          119                  5  4.5   4.0  9.70         0
# 172        322          110                  4  4.0   5.0  9.13         1
#
# [300 rows x 7 columns]

# %%
y_test
# Out:
# 132    0
# 309    0
# 341    0
# 196    0
# 246    0
#       ..
# 146    0
# 135    0
# 390    0
# 264    0
# 364    0
# Name: Admitted, Length: 100, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier =DecisionTreeClassifier(random_state=0)

# %%
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
y_pred = classifier.predict(x_test)

# %%
result= pd.DataFrame({'actual':y_test,'predicted': y_pred})

# %%
result.head()
# Out:
#      actual  predicted
# 132       0          0
# 309       0          0
# 341       0          0
# 196       0          0
# 246       0          0

# %%
from sklearn.metrics import ConfusionMatrixDisplay,accuracy_score
from sklearn.metrics import classification_report

# %%
cm = ConfusionMatrixDisplay.from_predictions(y_test,y_pred)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.95      0.94        80
#            1       0.78      0.70      0.74        20
#
#     accuracy                           0.90       100
#    macro avg       0.85      0.82      0.84       100
# weighted avg       0.90      0.90      0.90       100

# %%
y_pred2 = classifier.predict(x_train)

# %%
cm = ConfusionMatrixDisplay.from_predictions(y_train,y_pred2)

# %%
 accuracy_score(y_train,y_pred2)
# Out:
# 1.0

# %%
feature_names = ["GRE Score", "TOEFL Score", "University Rating", "SOP", "LOR ", "CGPA", "Research"]


x_single = pd.DataFrame([[320, 115, 5, 3.5, 3.9, 8.5, 1]], columns=feature_names)


y_single = classifier.predict(x_single)


if y_single[0] == 1:
    print('Student can be admitted')
else:
    print("Student can't be admitted")
# Out:
# Student can't be admitted

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(classifier,filled=True)
# Out:
# [Text(0.7125, 0.9375, 'x[5] <= 9.165\ngini = 0.354\nsamples = 300\nvalue = [231, 69]'),
#  Text(0.525, 0.8125, 'x[5] <= 9.055\ngini = 0.094\nsamples = 242\nvalue = [230, 12]'),
#  Text(0.61875, 0.875, 'True  '),
#  Text(0.3, 0.6875, 'x[0] <= 330.0\ngini = 0.036\nsamples = 221\nvalue = [217, 4]'),
#  Text(0.25, 0.5625, 'x[5] <= 8.92\ngini = 0.027\nsamples = 220\nvalue = [217, 3]'),
#  Text(0.1, 0.4375, 'x[4] <= 4.75\ngini = 0.01\nsamples = 201\nvalue = [200, 1]'),
#  Text(0.05, 0.3125, 'gini = 0.0\nsamples = 195\nvalue = [195, 0]'),
#  Text(0.15, 0.3125, 'x[1] <= 109.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.1, 0.1875, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2, 0.1875, 'x[3] <= 3.75\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.15, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.25, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.4, 0.4375, 'x[5] <= 8.95\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
# ...

# %%
cle_en =DecisionTreeClassifier(criterion ='entropy',random_state=0)

# %%
cle_en.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = cle_en.predict(x_test)

# %%
y2_pred2 = cle_en.predict(x_train)

# %%
cm = ConfusionMatrixDisplay.from_predictions(y_test,y_pred)

# %%
cm = ConfusionMatrixDisplay.from_predictions(y_train,y2_pred2)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.94

# %%
accuracy_score(y_train,y2_pred2)
# Out:
# 1.0

# %%
plot_tree(cle_en,filled=True)
# Out:
# [Text(0.625, 0.9375, 'x[5] <= 9.165\nentropy = 0.778\nsamples = 300\nvalue = [231, 69]'),
#  Text(0.39285714285714285, 0.8125, 'x[5] <= 8.92\nentropy = 0.285\nsamples = 242\nvalue = [230, 12]'),
#  Text(0.5089285714285714, 0.875, 'True  '),
#  Text(0.14285714285714285, 0.6875, 'x[4] <= 4.75\nentropy = 0.045\nsamples = 201\nvalue = [200, 1]'),
#  Text(0.07142857142857142, 0.5625, 'entropy = 0.0\nsamples = 195\nvalue = [195, 0]'),
#  Text(0.21428571428571427, 0.5625, 'x[1] <= 109.0\nentropy = 0.65\nsamples = 6\nvalue = [5, 1]'),
#  Text(0.14285714285714285, 0.4375, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(0.2857142857142857, 0.4375, 'x[0] <= 321.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(0.21428571428571427, 0.3125, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.35714285714285715, 0.3125, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6428571428571429, 0.6875, 'x[4] <= 3.75\nentropy = 0.839\nsamples = 41\nvalue = [30, 11]'),
# ...
