# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data1 = pd.read_csv("House_Price_dataset(1).csv")
data1
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0        2.0      3.0      yes        no       no
# 1    12250000  8960       4.0        4.0      4.0      yes        no       no
# 2    12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3    12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4    11410000  7420       4.0        1.0      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0        1.0      1.0      yes        no      yes
# 541   1767150  2400       3.0        1.0      1.0       no        no       no
# 542   1750000  3620       2.0        1.0      1.0      yes        no       no
# 543   1750000  2910       3.0        1.0      1.0       no        no       no
# 544   1750000  3850       3.0        1.0      2.0      yes        no       no
#
# ...

# %%
data1.shape
# Out:
# (545, 13)

# %%
data1.dtypes
# Out:
# price                 int64
# area                  int64
# bedrooms            float64
# bathrooms           float64
# stories             float64
# mainroad             object
# guestroom            object
# basement             object
# hotwaterheating      object
# airconditioning      object
# parking             float64
# prefarea             object
# furnishingstatus     object
# dtype: object

# %%
data1.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            5
# bathrooms           5
# stories             2
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             4
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
mean=data1.mean(numeric_only = True)
mean
# Out:
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.961111e+00
# bathrooms    1.285185e+00
# stories      1.804788e+00
# parking      6.913124e-01
# dtype: float64

# %%
median =data1.median(numeric_only = True)
median
# Out:
# price        4340000.0
# area            4600.0
# bedrooms           3.0
# bathrooms          1.0
# stories            2.0
# parking            0.0
# dtype: float64

# %%
mode =data1.mode(numeric_only = True)
mode
# Out:
#      price    area  bedrooms  bathrooms  stories  parking
# 0  3500000  6000.0       3.0        1.0      2.0      0.0
# 1  4200000     NaN       NaN        NaN      NaN      NaN

# %%
replace = data1.fillna(median, inplace=True)

# %%
replace

# %%
data1.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
plot = sb.scatterplot(data=data1, x="area",y="price")

# %%
furnish = data1["furnishingstatus" ]

# %%
sub =furnish.value_counts()
sub
# Out:
# furnishingstatus
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: count, dtype: int64

# %%
plot = plt.bar(sub.index,sub.values)
plt.title("furnishing-status")
# Out:
# Text(0.5, 1.0, 'furnishing-status')

# %%
base = data1["basement" ]

# %%
sub1= base.value_counts()

# %%
sub1
# Out:
# basement
# no     354
# yes    191
# Name: count, dtype: int64

# %%
plot = plt.bar(sub1.index ,sub1.values)
plot
# Out:
# <BarContainer object of 2 artists>

# %%
bed = data1["bedrooms" ]

# %%
sub2=bed.value_counts()
sub2
# Out:
# bedrooms
# 3.0    302
# 2.0    136
# 4.0     93
# 5.0     10
# 6.0      2
# 1.0      2
# Name: count, dtype: int64

# %%
plot =plt.bar(sub2.index,sub2.values)
plt.xlabel("beds")
plt.ylabel("counts")
# Out:
# Text(0, 0.5, 'counts')

# %%
aircondition = data1["airconditioning" ]

# %%
sub3 = aircondition.value_counts()
sub3
# Out:
# airconditioning
# no     373
# yes    172
# Name: count, dtype: int64

# %%
plt.bar(sub3.index,sub3.values)
# Out:
# <BarContainer object of 2 artists>

# %%
data1
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0        2.0      3.0      yes        no       no
# 1    12250000  8960       4.0        4.0      4.0      yes        no       no
# 2    12250000  9960       3.0        2.0      2.0      yes        no      yes
# 3    12215000  7500       4.0        2.0      2.0      yes        no      yes
# 4    11410000  7420       4.0        1.0      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0        1.0      1.0      yes        no      yes
# 541   1767150  2400       3.0        1.0      1.0       no        no       no
# 542   1750000  3620       2.0        1.0      1.0      yes        no       no
# 543   1750000  2910       3.0        1.0      1.0       no        no       no
# 544   1750000  3850       3.0        1.0      2.0      yes        no       no
#
# ...

# %%
data1.corr(numeric_only = True)
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366420   0.509123  0.420712  0.382167
# area       0.535997  1.000000  0.155350   0.189698  0.083996  0.352356
# bedrooms   0.366420  0.155350  1.000000   0.363977  0.406050  0.135066
# bathrooms  0.509123  0.189698  0.363977   1.000000  0.325548  0.180816
# stories    0.420712  0.083996  0.406050   0.325548  1.000000  0.053636
# parking    0.382167  0.352356  0.135066   0.180816  0.053636  1.000000

# %%
x = data1[["area"]]
y = data1[["price"]]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.25,random_state=40)

# %%
X_test
# Out:
#      area
# 42   6480
# 62   6240
# 0    7420
# 422  3720
# 112  4300
# ..    ...
# 28   7950
# 154  3650
# 19   6420
# 331  7260
# 537  1700
#
# [137 rows x 1 columns]

# %%
sub = data1[['area','price']]

# %%
sub
# Out:
#      area     price
# 0    7420  13300000
# 1    8960  12250000
# 2    9960  12250000
# 3    7500  12215000
# 4    7420  11410000
# ..    ...       ...
# 540  3000   1820000
# 541  2400   1767150
# 542  3620   1750000
# 543  2910   1750000
# 544  3850   1750000
#
# [545 rows x 2 columns]

# %%
r = LinearRegression().fit(X_train,Y_train)
predict = r.predict(X_test)
predict
# Out:
# array([[5287510.13948412],
#        [5181603.11606748],
#        [5702312.64786596],
#        [4069579.37019277],
#        [4325521.34344965],
#        [3937195.59092197],
#        [3579759.38689081],
#        [3657865.81666058],
#        [4832992.49732105],
#        [4369649.26987325],
#        [5075696.09265085],
#        [4149009.63775525],
#        [3751858.29994285],
#        [3381183.71798461],
#        [5075696.09265085],
#        [3238209.23637215],
#        [5234556.62777581],
#        [5340463.65119244],
#        [4193137.56417885],
#        [4034277.02905389],
#        [4369649.26987325],
#        [4016625.85848445],
#        [3751858.29994285],
#        [5261033.38362996],
#        [4210788.73474829],
#        [3698904.78823453],
#        [3731118.17452376],
#        [5031568.16622725],
#        [3981323.51734557],
#        [3857765.32335949],
#        [4899184.38695645],
#        [4987440.23980365],
#        [8252906.79515003],
#        [4038689.82169625],
# ...

# %%
plt.scatter(X_test,Y_test)
plt.plot(X_test,predict, color ="red")
plt.show()

# %%
print(r.score(X_test,Y_test))
# Out:
# 0.24687062930503212

# %%
r.coef_
# Out:
# array([[441.27926424]])

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score as r2
from sklearn.metrics import mean_absolute_error as mae
import sklearn.metrics

# %%
r2(Y_test,predict)
# Out:
# 0.24687062930503212

# %%
MSE =mse(Y_test,predict)
MSE
# Out:
# np.float64(3429470483986.9907)

# %%
mae(Y_test,predict)
# Out:
# np.float64(1359133.9859632493)

# %%
rmse = np.sqrt(MSE)
rmse
# Out:
# np.float64(1851882.9563411914)

# %%
predict1 = r.predict([[area:=7420]])
predict1
# Out:
# C:\Users\lenovo\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[5702312.64786596]])

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()

# %%
sub1 = data1['furnishingstatus']
sub2 = data1['mainroad']
sub3 =data1['guestroom']
sub4=data1['basement']
sub5 = data1['hotwaterheating']
sub6 = data1['airconditioning']
sub7 = data1['guestroom' ]
sub8= data1['prefarea']

# %%
le.fit(sub2)
le.fit(sub3)
le.fit(sub4)
le.fit(sub5)
le.fit(sub6)
le.fit(sub7)
le.fit(sub8)
# Out:
# LabelEncoder()

# %%
sub21 = le.transform(sub2)
sub31 = le.transform(sub3)
sub41 = le.transform(sub4)
sub51 = le.transform(sub5)
sub61 = le.transform(sub6)
sub71 = le.transform(sub7)
sub81 = le.transform(sub8)

# %%
data1['mainroad'] =sub21
data1['guestroom'] =sub31
data1['basement'] =sub41
data1['hotwaterheating'] =sub51
data1['airconditioning'] =sub61
data1['guestroom' ] = sub71
data1['prefarea'] =sub81

# %%
sub = data1['furnishingstatus']
le.fit(sub)
sub1 = le.transform(sub)
data1['furnishingstatus'] = sub1

# %%
data1[160:]
# Out:
#        price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 160  5460000  6210       4.0        1.0      4.0         1          1
# 161  5460000  6100       3.0        1.0      3.0         1          1
# 162  5460000  6600       4.0        2.0      2.0         1          1
# 163  5425000  6825       3.0        1.0      1.0         1          1
# 164  5390000  6710       3.0        2.0      2.0         1          1
# ..       ...   ...       ...        ...      ...       ...        ...
# 540  1820000  3000       2.0        1.0      1.0         1          0
# 541  1767150  2400       3.0        1.0      1.0         0          0
# 542  1750000  3620       2.0        1.0      1.0         1          0
# 543  1750000  2910       3.0        1.0      1.0         0          0
# 544  1750000  3850       3.0        1.0      2.0         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# ...

# %%
data1.corr()
# Out:
#                      price      area  bedrooms  bathrooms   stories  mainroad  \
# price             1.000000  0.535997  0.366420   0.509123  0.420712  0.296898
# area              0.535997  1.000000  0.155350   0.189698  0.083996  0.288874
# bedrooms          0.366420  0.155350  1.000000   0.363977  0.406050 -0.014103
# bathrooms         0.509123  0.189698  0.363977   1.000000  0.325548  0.039557
# stories           0.420712  0.083996  0.406050   0.325548  1.000000  0.121706
# mainroad          0.296898  0.288874 -0.014103   0.039557  0.121706  1.000000
# guestroom         0.255517  0.140297  0.083166   0.130280  0.043538  0.092337
# basement          0.187057  0.047417  0.101336   0.107814 -0.172394  0.044002
# hotwaterheating   0.093073 -0.009229  0.047312   0.068979  0.018847 -0.011781
# airconditioning   0.452954  0.222393  0.159206   0.184595  0.293602  0.105423
# parking           0.382167  0.352356  0.135066   0.180816  0.053636  0.201594
# ...

# %%
subset1 = data1[['area','bathrooms','stories','airconditioning','parking']]

# %%
X_train1, X_test1, Y_train1, Y_test1 = train_test_split(subset1, y, test_size=0.25, random_state=40)

# %%
Y_train1
# Out:
#         price
# 252   4515000
# 420   3360000
# 192   5040000
# 46    7525000
# 386   3535000
# ..        ...
# 440   3234000
# 165   5383000
# 7    10150000
# 219   4795000
# 326   3990000
#
# [408 rows x 1 columns]

# %%
r1 = LinearRegression().fit(X_train1,Y_train1)
predict11 = r1.predict(X_test1)
predict11
# Out:
# array([[7870773.77906455],
#        [6679718.69982005],
#        [7726040.00642061],
#        [4071013.24372567],
#        [3760549.94486757],
#        [3511459.71439137],
#        [5648358.80387682],
#        [2921477.15477124],
#        [5743789.65445325],
#        [3378048.2249509 ],
#        [6849462.54738934],
#        [3647327.11283293],
#        [3392575.74075501],
#        [3154807.79348227],
#        [7131893.33227685],
#        [2652289.87160889],
#        [5119790.45932732],
#        [6781619.24865122],
#        [4278645.86918772],
#        [3162924.84408509],
#        [3788855.65287623],
#        [3863916.51298002],
#        [3392575.74075501],
#        [4835267.35995945],
#        [3276147.67611973],
#        [2947801.46321929],
#        [4264715.89122459],
#        [5698035.45935696],
#        [3128957.9944747 ],
#        [4063522.48832192],
#        [4603160.55428845],
#        [7075281.91625954],
#        [6170457.05388592],
#        [3576562.84281129],
# ...

# %%
X_test1
# Out:
#      area  bathrooms  stories  airconditioning  parking
# 42   6480        2.0      4.0                1      2.0
# 62   6240        2.0      2.0                1      1.0
# 0    7420        2.0      3.0                1      2.0
# 422  3720        1.0      1.0                1      0.0
# 112  4300        1.0      2.0                0      0.0
# ..    ...        ...      ...              ...      ...
# 28   7950        2.0      2.0                0      2.0
# 154  3650        2.0      2.0                0      2.0
# 19   6420        2.0      2.0                1      1.0
# 331  7260        2.0      1.0                0      3.0
# 537  1700        1.0      2.0                0      0.0
#
# [137 rows x 5 columns]

# %%
r2(Y_test1,predict11)
# Out:
# 0.5389351925542872

# %%
MSE =mse(Y_test1,predict11)
MSE
# Out:
# np.float64(2099517307207.2864)

# %%
mae(Y_test1,predict11)
# Out:
# np.float64(1044785.6113465481)

# %%
rmse = np.sqrt(MSE)
rmse
# Out:
# np.float64(1448971.1202116094)

# %%
predict11 = r1.predict([[9860,1.0,1.0,0,0]])
predict11
# Out:
# C:\Users\lenovo\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[4923539.88222366]])
